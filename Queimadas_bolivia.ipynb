# %% [markdown]
# <a href="https://colab.research.google.com/github/GracielaQuevedo/Ocean_CienciaDados_24_02_2021/blob/main/Queimadas_bolivia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

queimadas = pd.read_csv('https://raw.githubusercontent.com/GracielaQuevedo/Repositorio_Python2021/main/historico_pais_bolivia.csv?token=ATC3GV2KEMZ7Q5QJ5LOIKWLAOSEFC')

# %%
queimadas
# Out:
#         Ano Janeiro Fevereiro Março  ... Outubro Novembro Dezembro  Total
# 0      1998       -         -     -  ...    1279      218      184   7747
# 1      1999      60       128    67  ...    3968      650      154  22618
# 2      2000     154       395   171  ...    2295      422       86  12269
# 3      2001      49        78    58  ...    2028      192       63  10900
# 4      2002     221        45    70  ...   11757     4412      498  40522
# 5      2003     239        65   109  ...    8728     2762      526  36423
# 6      2004     210       203   164  ...    8475     1419      268  60967
# 7      2005     222        84   146  ...    7057     1143      176  53237
# 8      2006      72        64    96  ...    4399     1823      124  44177
# 9      2007      80        94   105  ...   11059     1109      156  62362
# 10     2008      68        88    83  ...    9093     2360      690  41245
# 11     2009     253        89    95  ...    7693     1882      247  24032
# ...

# %%
queimadas_2003_2020 = queimadas.iloc[5:23,0:14]

# %%
queimadas_2003_2020
# Out:
#      Ano Janeiro Fevereiro Março  ... Outubro Novembro Dezembro  Total
# 5   2003     239        65   109  ...    8728     2762      526  36423
# 6   2004     210       203   164  ...    8475     1419      268  60967
# 7   2005     222        84   146  ...    7057     1143      176  53237
# 8   2006      72        64    96  ...    4399     1823      124  44177
# 9   2007      80        94   105  ...   11059     1109      156  62362
# 10  2008      68        88    83  ...    9093     2360      690  41245
# 11  2009     253        89    95  ...    7693     1882      247  24032
# 12  2010     127        84   131  ...    7562     3914     1329  83119
# 13  2011     137        37    96  ...    6189     2529      519  31762
# 14  2012     191        56   156  ...    5336      956      238  22708
# 15  2013     180        83   219  ...    1973     1435      479  17536
# 16  2014      69        99    83  ...    5605     1056      371  15891
# ...

# %%
import matplotlib.pyplot as plt

queimadas_2003_2020.plot(kind='bar', x='Ano', y='Total', color='gray', figsize=(6.69,4))

# change the default font family
plt.rcParams.update({'font.family':'Times New Roman'})
print(plt.rcParams['font.family'])
plt.rcParams.update({'font.size':9})


plt.xlabel('Ano', fontsize=10)
plt.ylabel('Focos de queimadas', fontsize=10)
#plt.title('Focos de queimadas da Bolívia')
#plt.savefig('Queimadas_bolivia.png', dpi=300)

#Tick Parameters
#plt.tick_params(axis='both',bottom=True, top=True, left=True, right=True, direction='in', which='major', grid_color='blue')
# Out:
# ['Times New Roman']
# Text(0, 0.5, 'Focos de queimadas')

# %%
media_anual = queimadas_2003_2020.Total.mean()

media_anual
# Out:
# 37996.333333333336

# %%
queimadas_2003_2020['Anomalias'] = ((queimadas_2003_2020['Total'] - media_anual)/media_anual)*100

# %%
queimadas_2003_2020
# Out:
#      Ano Janeiro Fevereiro Março  ... Novembro Dezembro  Total   Anomalias
# 5   2003     239        65   109  ...     2762      526  36423   -4.140750
# 6   2004     210       203   164  ...     1419      268  60967   60.454956
# 7   2005     222        84   146  ...     1143      176  53237   40.110888
# 8   2006      72        64    96  ...     1823      124  44177   16.266482
# 9   2007      80        94   105  ...     1109      156  62362   64.126363
# 10  2008      68        88    83  ...     2360      690  41245    8.549948
# 11  2009     253        89    95  ...     1882      247  24032  -36.751792
# 12  2010     127        84   131  ...     3914     1329  83119  118.755318
# 13  2011     137        37    96  ...     2529      519  31762  -16.407724
# 14  2012     191        56   156  ...      956      238  22708  -40.236339
# 15  2013     180        83   219  ...     1435      479  17536  -53.848178
# ...

# %%
cores = []
for numero in queimadas_2003_2020.Anomalias:
    if numero < 0:
        cores.append('blue')
    else:
        cores.append('red')
    
cores
# Out:
# ['blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red']

# %%
import matplotlib.pyplot as plt

queimadas_2003_2020.plot(kind='bar', x='Ano', y='Anomalias', color=cores, figsize=(6.69,4))


plt.xlabel('Tempo (Ano)', fontsize=12)
plt.ylabel('Anomalias (%)', fontsize=12)
#plt.title('Focos de queimadas da Bolívia')
#plt.savefig('Queimadas_bolivia.png', dpi=300)
plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
from scipy import signal
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline

Anos = queimadas_2003_2020.iloc[:,0]
QueimadasAnual = queimadas_2003_2020.iloc[:,13]
AnomaliasAnual = queimadas_2003_2020.iloc[:,-1]

# reset the plot configurations to default
plt.rcdefaults()

# change the default font family
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
print(plt.rcParams['font.serif'])

plt.rcParams.update({'font.size':8})
plt.rcParams['figure.figsize'] = (17/2.54,15/2.54)

cm = 1/2.54  # centimeters in inches
fig, axs = plt.subplots(2, dpi=100)

#fig.suptitle('Focos de queimadas')
axs[0].bar(Anos, QueimadasAnual, color='grey', width = 0.5)
axs[0].set_ylabel('Number of active fires', fontsize=10)
axs[0].set_facecolor('white')
axs[0].tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

axs[1].bar(Anos, AnomaliasAnual, color=cores, width = 0.5)
axs[1].set_ylabel('Anomalies of active fires (%)', fontsize=10)
axs[1].set_facecolor('white')
axs[1].tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

plt.tight_layout()

#fig.set_size_inches(17/2.54, 16/2.54)
from google.colab import files
plt.savefig('Queimadas_Bolivia.png', dpi=300, bbox_inches='tight', papertype='a4')
files.download("Queimadas_Bolivia.png") 

# change the fontsize of axes lables
#plt.rc('axes', labelsize=10)
# Out:
# ['Times New Roman', 'DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']

# %%
# !pip install bs4

# %%
from shapely.geometry import Point, LineString, Polygon
import geopandas as gpd
import contextily
import matplotlib.pyplot as plt
import seaborn as sns

import os
from urllib.request import urlretrieve
import requests
import zipfile
from bs4 import BeautifulSoup

# %%
import pandas as pd
import matplotlib.pyplot as plt

Queimadas_Departamentos = pd.read_csv('https://raw.githubusercontent.com/GracielaQuevedo/Repositorio_Python2021/main/Queimadas_Dept_Bolivia.csv?token=ATC3GVYOCY5LDLUXRPTNAL3AOUV4O')

# %%
Queimadas_Departamentos
# Out:
#     YEAR  EL BENI  SANTA CRUZ  COCHABAMBA  ...  TARIJA  CHUQUISACA  ORURO  POTOSI
# 0   2003    15948       12725        2061  ...     755        1258     57      36
# 1   2004    23270       31341        1867  ...     521         534     47      43
# 2   2005    25441       19318        1716  ...     606         706     86      46
# 3   2006    16806       21968        1320  ...     466         523     55      30
# 4   2007    16356       36898        2032  ...     696         969     57      42
# 5   2008    16131       17863        1848  ...     560         775    125      73
# 6   2009     9059       10400         705  ...     653         701     67      58
# 7   2010    33169       40523        2339  ...     613         891     74      71
# 8   2011    14151       13794        1157  ...     480         381     37      25
# 9   2012    10528        8180         941  ...     356         359     48      39
# ...

# %%
Anos = Queimadas_Departamentos.iloc[:,0]
Santa_Cruz = Queimadas_Departamentos.iloc[:,2]
Beni = Queimadas_Departamentos.iloc[:,1]
Cochabamba = Queimadas_Departamentos.iloc[:,3]
Pando = Queimadas_Departamentos.iloc[:,4]
La_Paz = Queimadas_Departamentos.iloc[:,5]
Tarija = Queimadas_Departamentos.iloc[:,6]
Chuquisaca = Queimadas_Departamentos.iloc[:,7]
Oruro = Queimadas_Departamentos.iloc[:,8]
Potosi = Queimadas_Departamentos.iloc[:,9]

# %%
fig, axs = plt.subplots(5, 2, figsize=(9,10), sharex=True)

axs[0, 0].bar(Anos, Santa_Cruz, color='grey', width = 0.5)
axs[0, 0].set_ylabel('Número de Focos', fontsize=10)
#axs[SC].set_facecolor('white')
axs[0, 1].bar(Anos, Beni, color='grey', width = 0.5)

axs[1, 0].bar(Anos, Cochabamba, color='grey', width = 0.5)

axs[1, 1].bar(Anos, Pando, color='grey', width = 0.5)

axs[2, 0].bar(Anos, La_Paz, color='grey', width = 0.5)

axs[2, 1].bar(Anos, Tarija, color='grey', width = 0.5)

axs[3, 0].bar(Anos, Chuquisaca, color='grey', width = 0.5)

axs[3, 1].bar(Anos, Oruro, color='grey', width = 0.5)

axs[4, 0].bar(Anos, Potosi, color='grey', width = 0.5)

axs[4, 1].axis('off')
# Out:
# (2001.875, 2021.125, 0.0, 1.0)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8), (ax9, ax10)) = plt.subplots(nrows=5, ncols=2, sharex=False, sharey=False, dpi=100)

# reset the plot configurations to default
plt.rcdefaults()

# change the default font family
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
print(plt.rcParams['font.serif'])

plt.rcParams.update({'font.size':8})
plt.rcParams['figure.figsize'] = (17/2.54,22/2.54)

ax1.bar(Anos, Santa_Cruz, color='grey')
ax1.set_xticks(Anos[::5])
ax1.set_xticklabels(Anos[::5])
ax1.set_title('Santa Cruz', fontsize=10)
ax1.set_ylabel('Number of\n active fire', fontsize=10)
ax1.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax2.bar(Anos, Beni, color='grey')
ax2.set_xticks(Anos[::5])
ax2.set_xticklabels(Anos[::5])
ax2.set_title('Beni', fontsize=10)
#ax2.set_ylabel('Number of\n active fire')
ax2.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax3.bar(Anos, Cochabamba, color='grey')
ax3.set_xticks(Anos[::5])
ax3.set_xticklabels(Anos[::5])
ax3.set_title('Cochabamba', fontsize=10)
ax3.set_ylabel('Number of\n active fire', fontsize=10)
ax3.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax4.bar(Anos, Pando, color='grey')
ax4.set_xticks(Anos[::5])
ax4.set_xticklabels(Anos[::5])
ax4.set_title('Pando', fontsize=10)
#ax4.set_ylabel('Number of\n active fire')
ax4.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax5.bar(Anos, La_Paz, color='grey')
ax5.set_xticks(Anos[::5])
ax5.set_xticklabels(Anos[::5])
ax5.set_title('La Paz', fontsize=10)
ax5.set_ylabel('Number of\n active fire', fontsize=10)
ax5.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax6.bar(Anos, Tarija, color='grey')
ax6.set_xticks(Anos[::5])
ax6.set_xticklabels(Anos[::5])
ax6.set_title('Tarija', fontsize=10)
#ax6.set_ylabel('Number of\n active fire')
ax6.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax7.bar(Anos, Chuquisaca, color='grey')
ax7.set_xticks(Anos[::5])
ax7.set_xticklabels(Anos[::5])
ax7.set_title('Chuquisaca', fontsize=10)
ax7.set_ylabel('Number of\n active fire', fontsize=10)
ax7.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax8.bar(Anos, Oruro, color='grey')
ax8.set_xticks(Anos[::5])
ax8.set_xticklabels(Anos[::5])
ax8.set_title('Oruro', fontsize=10)
#ax8.set_ylabel('Number of\n active fire')
ax8.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax9.bar(Anos, Potosi, color='grey')
ax9.set_xticks(Anos[::5])
ax9.set_xticklabels(Anos[::5])
ax9.set_title('Potosi', fontsize=10)
ax9.set_ylabel('Number of\n active fire', fontsize=10)
ax9.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

ax10.axis('off')

fig.tight_layout()


#fig.set_size_inches(17/2.54, 16/2.54)
from google.colab import files
plt.savefig('Queimadas_Departamentos.png', dpi=300, bbox_inches='tight', papertype='a4')
files.download("Queimadas_Departamentos.png")

plt.show()
# Out:
# ['Times New Roman', 'DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,17), dpi=100, facecolor=None)

# reset the plot configurations to default
plt.rcdefaults()
# change the default font family
plt.rcParams.update({'font.family':'Times New Roman'})
print(plt.rcParams['font.family'])
plt.rcParams.update({'font.size':8})
plt.rcParams['figure.figsize'] = (17/2.54,15/2.54)

plt.subplot(5, 2, 1)
plt.bar(Anos, Santa_Cruz, color='grey', width=0.5)
plt.title('Santa Cruz')

plt.subplot(5, 2, 2)
plt.bar(Anos, Beni)
plt.title('Beni')

plt.subplot(5, 2, 3)
plt.bar(Anos, Cochabamba)
plt.title('Cochabamba')

plt.subplot(5, 2, 4)
plt.bar(Anos, Pando)
plt.title('Pando')

plt.subplot(5, 2, 5)
plt.bar(Anos, La_Paz)
plt.title('La Paz')

plt.subplot(5, 2, 6)
plt.bar(Anos, Tarija)
plt.title('Tarija')

plt.subplot(5, 2, 7)
plt.bar(Anos, Chuquisaca)
plt.title('chuquisaca')

plt.subplot(5, 2, 8)
plt.bar(Anos, Oruro)
plt.title('Oruro')

plt.subplot(5, 2, 9)
plt.bar(Anos, Potosi)
plt.title('Potosi')


plt.show()

'''
from google.colab import files
plt.savefig('Queimadas_Bolivia.png', dpi=300, bbox_inches='tight', papertype='a4')
files.download("Queimadas_Bolivia.png") 
'''
# Out:
# ['Times New Roman']
# '\nfrom google.colab import files\nplt.savefig(\'Queimadas_Bolivia.png\', dpi=300, bbox_inches=\'tight\', papertype=\'a4\')\nfiles.download("Queimadas_Bolivia.png") \n'

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

fig = plt.figure(figsize=(8,12))

plt.subplot(521)
plt.title('Santa Cruz')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'SANTA CRUZ')

ax_2=fig.add_subplot(522)
plt.title('Beni')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'EL BENI')

ax_3=fig.add_subplot(523)
plt.title('Cochabamba')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'COCHABAMBA')

ax_4=fig.add_subplot(524)
plt.title('Pando')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'PANDO')

ax_5=fig.add_subplot(525)
plt.title('La Paz')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'LA PAZ')


ax_6=fig.add_subplot(526)
plt.title('Tarija')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'TARIJA')

ax_7=fig.add_subplot(527)
plt.title('Chuquisaca')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'CHUQUISACA')

ax_8=fig.add_subplot(528)
plt.title('Oruro')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'ORURO')

ax_9=fig.add_subplot(529)
plt.title('Potosi')
sns.barplot(data = Queimadas_Departamentos, x= 'YEAR', y = 'POTOSI')

#fig.suptitle("Figure with multiple Subplots")


plt.show()

# %%
mean_SC = Santa_Cruz.mean()
mean_BN = Beni.mean()
mean_CB = Cochabamba.mean()
mean_PD = Pando.mean()
mean_LP = La_Paz.mean()
mean_CH = Chuquisaca.mean()
mean_TJ = Tarija.mean()
mean_OR = Oruro.mean()
mean_PT = Potosi.mean()

# %%
Anomalias_Dpto = pd.DataFrame(Queimadas_Departamentos, columns = ['YEAR'])

print(Anomalias_Dpto)
# Out:
#     YEAR
# 0   2003
# 1   2004
# 2   2005
# 3   2006
# 4   2007
# 5   2008
# 6   2009
# 7   2010
# 8   2011
# 9   2012
# 10  2013
# 11  2014
# 12  2015
# 13  2016
# 14  2017
# 15  2018
# 16  2019
# 17  2020

# %%
Anomalias_Dpto['Santa Cruz'] = ((Queimadas_Departamentos['SANTA CRUZ'] - mean_SC)/mean_SC)*100
Anomalias_Dpto['Beni'] = ((Queimadas_Departamentos['EL BENI'] - mean_BN)/mean_BN)*100
Anomalias_Dpto['Cochabamba'] = ((Queimadas_Departamentos['COCHABAMBA'] - mean_CB)/mean_CB)*100
Anomalias_Dpto['Pando'] = ((Queimadas_Departamentos['PANDO'] - mean_PD)/mean_PD)*100
Anomalias_Dpto['La Paz'] = ((Queimadas_Departamentos['LA PAZ'] - mean_LP)/mean_LP)*100
Anomalias_Dpto['Chuquisaca'] = ((Queimadas_Departamentos['CHUQUISACA'] - mean_CH)/mean_CH)*100
Anomalias_Dpto['Tarija'] = ((Queimadas_Departamentos['TARIJA'] - mean_TJ)/mean_TJ)*100
Anomalias_Dpto['Oruro'] = ((Queimadas_Departamentos['ORURO'] - mean_OR)/mean_OR)*100
Anomalias_Dpto['Potosi'] = ((Queimadas_Departamentos['POTOSI'] - mean_PT)/mean_PT)*100

# %%
Anomalias_Dpto
# Out:
#     YEAR  Santa Cruz        Beni  ...     Tarija      Oruro     Potosi
# 0   2003  -26.358533    5.850338  ...  69.282511 -14.784053 -34.808853
# 1   2004   81.375027   54.448042  ...  16.816143 -29.734219 -22.132797
# 2   2005   11.796138   68.857440  ...  35.874439  28.571429 -16.700201
# 3   2006   27.132082   11.545070  ...   4.484305 -17.774086 -45.674044
# 4   2007  113.534212    8.558323  ...  56.053812 -14.784053 -23.943662
# 5   2008    3.375837    7.064949  ...  25.560538  86.877076  32.193159
# 6   2009  -39.813654  -39.873450  ...  46.412556   0.166113   5.030181
# 7   2010  134.512626  120.149854  ...  37.443946  10.631229  28.571429
# 8   2011  -20.172071   -6.076741  ...   7.623318 -44.684385 -54.728370
# 9   2012  -52.661124  -30.123378  ... -20.179372 -28.239203 -29.376258
# 10  2013  -68.529486  -45.023931  ...   1.121076  52.491694  17.706237
# 11  2014  -65.936843  -56.300563  ... -60.089686  30.066445  28.571429
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# reset the plot configurations to default
plt.rcdefaults()

# change the default font family
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
print(plt.rcParams['font.serif'])

plt.rcParams.update({'font.size':8})
plt.rcParams['figure.figsize'] = (17/2.54,10/2.54)

ax = plt.gca()
#fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=, sharex=False, sharey=False, dpi=100)

ax.set_xticks(Anos[::1])
ax.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')

Anomalias_Dpto.plot(ax=ax, kind='line', x='YEAR', y='Santa Cruz', marker='o')
Anomalias_Dpto.plot(ax=ax, kind='line', x='YEAR', y='Beni', color='red', marker='o')
Anomalias_Dpto.plot(ax=ax, kind='line', x='YEAR', y='Cochabamba', color='g', marker='o')
Anomalias_Dpto.plot(ax=ax, kind='line', x='YEAR', y='Pando', color='y', marker='o')
Anomalias_Dpto.plot(ax=ax, kind='line', x='YEAR', y='La Paz', color='c', marker='o')

plt.ylabel('Anomalies of active fires', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# ['Times New Roman', 'DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']

# %%
import pandas as pd

Queimadas_mensal = pd.read_csv('https://raw.githubusercontent.com/GracielaQuevedo/Repositorio_Python2021/main/Queimadas_Mensal.csv?token=ATC3GV7OYSPYHHM367TXZ3LAO5YEU')

# %%
Queimadas_mensal.head()
# Out:
#    Jan  Feb  Mar  Apr   May   Jun   Jul    Aug    Sep    Oct   Nov  Dec
# 0  239   65  109  231   427   682  5469   8022   9163   8728  2762  526
# 1  210  203  164  209   499  1149  3610  14196  30565   8475  1419  268
# 2  222   84  146  318   607  1700  4689  16596  20499   7057  1143  176
# 3   72   64   96  176  1448   884  4407  16773  13911   4399  1823  124
# 4   80   94  105  163   454  1874  2912  16164  28192  11059  1109  156

# %%
Valor_Sasonal = [58.5, 37.0, 2.5, 1.9]
Labels =['Spring', 'Winter', 'Autumn', 'Summer']

type(Valor_Sasonal)
# Out:
# list

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# reset the plot configurations to default
plt.rcdefaults()

# change the default font family
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
print(plt.rcParams['font.serif'])

plt.rcParams.update({'font.size':8})
plt.rcParams['figure.figsize'] = (17/2.54,8/2.54)

plt.subplot(1, 2, 1)
ax = Queimadas_mensal.boxplot(column=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], color='black', grid=False, widths=0.5)
plt.ylabel('Number of active fires', fontsize=10)
plt.xticks(rotation = 90)
ax.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')
plt.text(.8, 1000, 'D')
plt.text(1.8, 1300, 'D')
plt.text(2.8, 1400, 'D')
plt.text(3.8, 1800, 'D')
plt.text(4.8, 2500, 'D')
plt.text(5.8, 3900, 'D')
plt.text(6.5, 7000, 'C;D')
plt.text(7.5, 17500, 'A;B')
plt.text(8.8, 31100, 'A')
plt.text(9.5, 12900, 'B;C')
plt.text(10.8, 7000, 'D')
plt.text(11.8, 2400, 'D')
plt.tight_layout()

plt.subplot(1, 2, 2)
ax = plt.bar(Labels, Valor_Sasonal, color='gray', width=0.5)
plt.ylabel('Frequency (%)', fontsize=10)
plt.tick_params(axis='both',bottom=True, left=True, direction='in', which='major')
plt.text(-0.26, 59, '58.5%')
plt.text(0.75, 37.5, '37.0%')
plt.text(1.77, 3, '2.5%')
plt.text(2.77, 2.4, '1.9%')
plt.tight_layout()

#fig.set_size_inches(17/2.54, 16/2.54)
from google.colab import files
plt.savefig('Fig5.png', dpi=300, bbox_inches='tight', papertype='a4')
files.download("Fig5.png")


plt.show()
# Out:
# ['Times New Roman', 'DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']

# %%
import pandas as pd 

Densidade = pd.read_csv('https://raw.githubusercontent.com/GracielaQuevedo/Repositorio_Python2021/main/Densidade_Dep.csv?token=ATC3GVZZYEE5XL7XLSNWJ5DAO6DGUDen')

# %%
Densidade.head()
# Out:
#   Departamentos   Total  Densidade
# 0            BE  271198        1.3
# 1            SC  311034        0.8
# 2            CB   23680        0.4
# 3            PD   21991        0.3
# 4            LP   35379        0.3

# %%
Densidade.dtypes
# Out:
# Departamentos     object
# Total              int64
# Densidade        float64
# dtype: object

# %%
Departamentos =

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
import seaborn as sns

# reset the plot configurations to default
plt.rcdefaults()

# change the default font family
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
print(plt.rcParams['font.serif'])

plt.rcParams.update({'font.size':8})
plt.rcParams['figure.figsize'] = (8.5/2.54,14/2.54)

plt.subplot(2, 1, 1)
sns.barplot(data=Densidade, x='Departamentos', y='Total', color='gray')
plt.ylabel('Total distribution\n of active fires', fontsize=10)
plt.xlabel('')

plt.subplot(2, 1, 2)
sns.barplot(data=Densidade, x='Departamentos', y='Densidade', color='gray')
plt.ylabel('Density of active\n fires/area (km$^2$)', fontsize=10)
plt.xlabel('Bolivia Departments', fontsize=10)

plt.tight_layout()

#fig.set_size_inches(17/2.54, 16/2.54)
from google.colab import files
plt.savefig('Fig6.png', dpi=300, bbox_inches='tight', papertype='a4')
files.download("Fig6.png")

plt.show()
# Out:
# ['Times New Roman', 'DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
